# %%
using DifferentialEquations
using Plots

# %%
function mass_no_friction(du, u, p, t)
    
    # Unpack parameters 
    m = p[1] # mass
    controller = p[2] # Controller
    
    du[1] = u[2]
    du[2] = controller(u[1], u[2])/m    
end
# Out:
# mass_no_friction (generic function with 1 method)

# %%
f(x,y) = 2.0;
mass_no_friction([0,0], [1.0, 0.0], [1.0, f], 5.0)
# Out:
# 2.0

# %%
# Parameters
m = 1.0;

# No control
τ(u1,u2) = 0.0;

p = [m, τ];

# Time span
tspan = (0.0, 10.0)

# Initial Conditions
x0 = [1.0, 0.0];

# %%
prob = ODEProblem(mass_no_friction, x0, tspan, p);
sol  = solve(prob, reltol=1e-8, abstol=1e-8);

# %%
plot(sol)

# %%
# PD Control
Kp = 100.0
Kd = 100.0
τ1(u1,u2) = -Kp*u1 - Kd*u2;

p1 = [m, τ1];

# %%
prob = ODEProblem(mass_no_friction, x0, tspan, p1);
sol  = solve(prob, reltol=1e-8, abstol=1e-8);
plot(sol)

# %%
# Adaptive Control Scheme (MRAC)

function adaptive_control_mass(desired)
    # Unpack desired trajectories
    x_d     = desired[1] # Desired position
    xdot_d  = desired[2] # Desired velocity
    xddot_d = desired[3] # Desired acceleration
    lambda  = desired[4] # Desired convergence rate
    γ       = desired[5] # Desired learning rate
    
    # Simplifications
    x_tilde(t, u1, u2)    = u1 - x_d(t)
    xdot_tilde(t, u1, u2) = u2 - xdot_d(t)
    v(t, u1, u2) = xddot_d(t) - 2*lambda*xdot_tilde(t, u1, u2) - lambda^2*x_tilde(t, u1, u2)
    s(t, u1, u2) = xdot_tilde(t, u1, u2) + lambda*x_tilde(t, u1, u2)
    
    # Controller design
    controller(u1,u2,u3,t) = u3*v(t, u1, u2)
    adapt_law(u1,u2,u3,t)  = -γ*v(t, u1, u2)*s(t, u1, u2)
    
    return controller, adapt_law
end
# Out:
# adaptive_control_mass (generic function with 1 method)

# %%
function mass_adaptive(du, u, p, t)
    
    # Unpack parameters 
    m          = p[1] # mass
    controller = p[2] # Controller
    adapt_law  = p[3] # Adaptation Law
    
    du[1] = u[2] # xdot             
    du[2] = controller(u[1], u[2], u[3], t)/m  # xddot 
    du[3] = adapt_law(u[1], u[2], u[3], t) # m_dot
end
# Out:
# mass_adaptive (generic function with 1 method)

# %%
using ForwardDiff

# %%
# Define the desired trajectories
x_ur(t)    = square(t)
x_ul(t)    = integrate(x_ur(t))
x_d(t)     = integrate(x_ul(t))
xdot_d(t)  = ForwardDiff.derivative(x_d, t)# 2*cos(2*t) 
xddot_d(t) = ForwardDiff.derivative(xdot_d, t)# -4*sin(2*t)

# Define rates
conv_rate    = 1. # Convergence rate
learn_rate   = 1. # Learning rate

# Generate controller and adaptation law
desired_params = [x_d, xdot_d, xddot_d, conv_rate, learn_rate] 
u_control, adapt = adaptive_control_mass(desired_params)
# Out:
# (controller, adapt_law)

# %%
function accum(f)
    
    sum = 0
    lst = []
    
    for i in f
        sum += i
        append!(lst,sum)
    end
    return lst
end
# Out:
# accum (generic function with 1 method)

# %%
function sqr(t)
    
    if t % 2*pi

# %%
a = [1, 2, 3]
accum(a)
# Out:
# 3-element Array{Any,1}:
#  1
#  3
#  6

# %%
ts = 1:1000
function square(t)
    square = []
    for i in t
        if i%100 < 50
            append!(square,1)
        else
            append!(square,-1)
        end
    end
    return square
end

# square(t) = if t%10 < 5 return 1

# function square(t)
#     if t%10 < 5
#         return 1
#     else
#         return -1
#     end
# end

integrate(f) = accum(f) - 0.5*reduce(max,f)
# Out:
# integrate (generic function with 1 method)

# %%
plot(1:100,x_d(1:100), linewidth=3.0)
# Out:
# WARNING: rem(A::AbstractArray, B::Number) is deprecated, use rem.(A, B) instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at ./deprecated.jl:70
#  [2] rem(::UnitRange{Int64}, ::Int64) at ./deprecated.jl:57
#  [3] square at ./In[60]:17 [inlined]
#  [4] x_ur(::UnitRange{Int64}) at ./In[61]:2
#  [5] x_ul at ./In[61]:3 [inlined]
#  [6] x_d(::UnitRange{Int64}) at ./In[61]:4
#  [7] include_string(::String, ::String) at ./loading.jl:522
#  [8] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /home/luke/.julia/v0.6/IJulia/src/execute_request.jl:158
#  [9] (::Compat.#inner#17{Array{Any,1},IJulia.#execute_request,Tuple{ZMQ.Socket,IJulia.Msg}})() at /home/luke/.julia/v0.6/Compat/src/Compat.jl:385
#  [10] eventloop(::ZMQ.Socket) at /home/luke/.julia/v0.6/IJulia/src/eventloop.jl:8
#  [11] (::IJulia.##14#17)() at ./task.jl:335
# while loading In[63], in expression starting on line 1
# MethodError: no method matching isless(::Array{Int64,1}, ::Int64)
# Closest candidates are:
#   isless(::Missings.Missing, ::Any) at /home/luke/.julia/v0.6/Missings/src/Missings.jl:74
#   isless(::AbstractFloat, ::Real) at operators.jl:98
#   isless(::ForwardDiff.Dual{Tx,V,N} where N where V<:Real, ::Integer) where Tx at /home/luke/.julia/v0.6/ForwardDiff/src/dual.jl:104
#   ...
#
# Stacktrace:
#  [1] square at ./In[60]:17 [inlined]
#  [2] x_ur(::UnitRange{Int64}) at ./In[61]:2
#  [3] x_ul at ./In[61]:3 [inlined]
#  [4] x_d(::UnitRange{Int64}) at ./In[61]:4

# %%
# Setup control
x0 = [rand(), rand(), rand()]
println("Initial Condition: ", x0)

tspan = (0.0, 50.0)

# Parameters vector
# Define new mass
m = 10.0*rand();
println("Target Mass: ", m)

params = [m, u_control, adapt];
# Out:
# Initial Condition: [0.174509, 0.152177, 0.770512]
# Target Mass: 9.178667439057119

# %%
prob = ODEProblem(mass_adaptive, x0, tspan, params);
sol  = solve(prob, reltol=1e-8, abstol=1e-8);

# %%
plot(sol.t, x_d(sol.t), linewidth=3.0)
# plot(sol.t, zeros(size(sol.t)), linewidth=3.0)
plot!(sol,vars=(0,1))
# plot!(sol,var=(0,2))
# Out:
# WARNING: sign(A::AbstractArray) is deprecated, use sign.(A) instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at ./deprecated.jl:70
#  [2] sign(::Array{Float64,1}) at ./deprecated.jl:57
#  [3] x_d(::Array{Float64,1}) at ./In[13]:2
#  [4] include_string(::String, ::String) at ./loading.jl:522
#  [5] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /home/luke/.julia/v0.6/IJulia/src/execute_request.jl:158
#  [6] (::Compat.#inner#17{Array{Any,1},IJulia.#execute_request,Tuple{ZMQ.Socket,IJulia.Msg}})() at /home/luke/.julia/v0.6/Compat/src/Compat.jl:385
#  [7] eventloop(::ZMQ.Socket) at /home/luke/.julia/v0.6/IJulia/src/eventloop.jl:8
#  [8] (::IJulia.##14#17)() at ./task.jl:335
# while loading In[16], in expression starting on line 1

# %%
plot(sol, vars=(0,3))
plot!(sol.t, m*ones(size(sol.t)), linewidth=3.0)

# %%
println(sol[3,end])
size(sol.t)
# Out:
# 32.550427773666186
# (1739,)

# %%
using Plots
gr()
# Out:
# Plots.GRBackend()

# %%
println(length(sol.t))
# Out:
# 2282

# %%
# initial = x0[1:2]
# num_time_steps = length(sol.t)
num_time_steps = 200

scatter([sol[1,1]], [0],linewidth=7, xlim=(-1.0, 1.0), ylim=(-0.5, 0.5), legend=false, marker=(:square,5))
anim = @animate for i = 1:num_time_steps
    # Plot the current position
    scatter([sol[1,i]], [0],xlim=(-1.0, 1.0), ylim=(-0.5,0.5), linewidth=5,marker=(:square,5))
    
    
end
gif(anim, "double_integrator.gif", fps=30)
# Out:
# INFO: Saved animation to /home/luke/workspace/2.152_project/double_integrator.gif
# Plots.AnimatedGif("/home/luke/workspace/2.152_project/double_integrator.gif")
